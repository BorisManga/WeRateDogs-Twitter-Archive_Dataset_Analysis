# %% [markdown]
# ## Report: act_report
# * Create a **250-word-minimum written report** called "act_report.pdf" or "act_report.html" that communicates the insights and displays the visualization(s) produced from your wrangled data. This is to be framed as an external document, like a blog post or magazine article, for example.

# %% [markdown]
# # WE RATE DOGS TWITTER ARCHIVE DATA WRANGLING

# %% [markdown]
# In this project we have analyzed the data called **We Rate Dogs** from Twitter archive provided to us in the project
# To have the complete data needed in the project, we have to gather additional data from various source programmatically :
# * **Predictions** : Predictions from an url provided in the project. The file contains dog's predictions (algorithm, confidence level ,a nd dog predcition)
# * **Json twitter data** : Additional data from Twitter archive. The dta obtained by query on Twitter API. The data contains retweet counts and favourite counts

# %% [markdown]
# After gatherign all the data =, we need to assess ans clean all the 3 data sets :
#     * Twitter_archive
#     * predictions
#     * Twitter json data
# We have detected more than 8 Quality issues and 3 Tidiness issues
# We have also cleaned all those issues detected

# %% [markdown]
# After assessing and celaning the 3 Data, we have merged all of them in a master data called **twitter_archive_master.csv**

# %% [markdown]
# ## Insights

# %% [markdown]
# ### Top rating notes used

# %% [markdown]
# The most used note is **12**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### The top dog stage in the data set

# %% [markdown]
# The dog stage is not provided for **83.70%** of dogs
#
# The prefered dog stage is Puppy for the values different from None
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### The dog picture for the top favourite tweet

# %% [markdown]
# Here below is the dog picture for the top favourite tweet : **132810 favourite counts**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## The top 15 Breed aggregated by favourite counts

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Golden_retriever is the top favourite Breed with 1915928 favourite counts

# %% [markdown]
# ## Top breed per retweet counts

# %% [markdown]
# The **Golden_Retriever** is still the top breed even for Retweet counts with **575585** retweet counts

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Top Tweet source

# %% [markdown]
# Most of the tweets are from **iPhone users** with **2012** tweets : **93.84%**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
